# %% [markdown]
# ![](public/mu.png)
# # Manchester United

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("data/2020-2021.csv")

# %%
mu_home_matches = data[data['HomeTeam'] == 'Man United']
mu_away_matches = data[data['AwayTeam'] == 'Man United']
mu_matches = pd.concat([mu_home_matches, mu_away_matches])
mu_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 10 to 379
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(82), int64(16), object(8)
# memory usage: 31.8+ KB

# %%
mu_matches.head()
# Out:
#    Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 10  E0  19/09/2020  17:30  Man United  Crystal Palace     1     3   A     0
# 36  E0  04/10/2020  16:30  Man United       Tottenham     1     6   A     1
# 51  E0  24/10/2020  17:30  Man United         Chelsea     0     0   D     0
# 64  E0  01/11/2020  16:30  Man United         Arsenal     0     1   A     0
# 81  E0  21/11/2020  20:00  Man United       West Brom     1     0   H     0
#
#     HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 10     1  ...     2.22 -1.25      1.86      2.04   1.90   2.04     1.91
# 36     4  ...     2.12 -0.25      1.77      2.02   1.84   2.11     1.85
# 51     0  ...     2.17  0.00      1.93      2.00   1.93   2.00     1.98
# 64     0  ...     1.95 -0.50      2.00      1.90   2.03   1.90     2.05
# 81     0  ...     2.43 -1.50      1.98      1.95   1.99   1.93     2.01
#
#     MaxCAHA  AvgCAHH  AvgCAHA
# 10     2.08     1.86     2.02
# ...
